# %%
import pandas as pd
import datacompy
import gc

# Fichier à valider
to_validate_file = 'input/alignements_AI-P2_20231108.tsv'

# Informations bibliographiques
bib_records_file = '20231010_rnv_id_with_title_editor.csv'

# %%
to_validate_data = pd.read_csv(to_validate_file, sep='\t', dtype = str)
bib_data = pd.read_csv(bib_records_file, dtype = str)

# On ne conserve que les non-alignements manuels et externes
ouali_no_align = to_validate_data.query('`nombre de candidats` == "0" & `décision d\'alignement` != "auto"').copy()
print('Non-alignements Ouali à valider: ' + str(len(ouali_no_align)))
# Out:
# Non-alignements Ouali à valider: 7827

# %%
display(ouali_no_align.head())
# Out:
#    réservoir source           id source       forme principale source arbitre  \
# 0   rnv-nz-auth-atc  981023132827302851                 Daniel, Marie    7035
# 7   rnv-nz-auth-atc  981023265136402851                Tavares, Vânia    8206
# 31  rnv-nz-auth-atc  981023280192102851  Spring, David, journaliste      8153
# 53  rnv-nz-auth-atc  981023280283502851        Zacharie, de Lisieux      8153
# 57  rnv-nz-auth-atc  981023280312002851     Savoye, Marie-Catherine       NaN
#
#              date d'arbitrage niveau de confiance commentaire  \
# 0   12/09/2023 - 14:29:06.065             Certain         NaN
# 7   07/04/2022 - 14:22:06.553             Certain         NaN
# 31  16/08/2022 - 23:03:48.236             Certain         NaN
# 53  16/08/2022 - 23:04:59.469             Certain         NaN
# 57                        NaN                 NaN         NaN
#
#    décision d'alignement nombre de candidats score algo max  ...   id cible  \
# ...
