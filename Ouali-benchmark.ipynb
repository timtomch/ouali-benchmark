# %%
import pandas as pd
import datacompy
benchmark_file = 'input/benchmark-nomsATC.tsv'
rero_files = ['input/RERO-aligned-1.txt', 'input/RERO-aligned-2.txt']
rero_concord_file = 'input/20220228_concordances_id_rnv_id_rero_4_headings.csv'

# %% [markdown]
# Import all data into dataframes. Specifying the `dtype` appears necessary because otherwise pandas doesn't know what to do with columns containing both numbers and text.

# %%
ouali_data = pd.read_csv(benchmark_file, sep='\t', dtype = str)
rero_data = pd.concat((pd.read_csv(f, sep='\t', encoding = "ISO-8859-1", dtype = str) for f in rero_files))
rero_data.columns =[column.replace(" ", "_") for column in rero_data.columns]
rero_concord = pd.read_csv(rero_concord_file, dtype = str)

# %%
rero_data.query('author_heading == "A, Cheng"')
# Out:
# Empty DataFrame
# Columns: [rero_id, idref_id, author_heading, subject_heading]
# Index: []

# %% [markdown]
# Not sure why the dataframe query doesn't seem to work with strings. Maybe because of extra spaces? Using loc and contains works better. `na=False` is required because that column contains `NaN` data, which we need to convert to false in order to use loc lookup.

# %%
display(rero_data.loc[rero_data['author_heading'].str.contains("Christen-Gueissaz", na=False)])
display(rero_concord.loc[rero_concord['main_form'].str.contains("Christen-Gueissaz", na=False)])
# Out:
#          rero_id   idref_id               author_heading subject_heading
# 6474  A000036058  033273901  Christen-Gueissaz, Eliane               NaN
#                    id             id_rnv              id_rero id_rero_a  \
# 3  981023303674702851  (RNV_A)0000149055  (RERO)vtls000036058       NaN
#
#                      main_form          repo_id
# 3  Christen-Gueissaz, Eliane    rnv-nz-auth-atc

# %%
display(rero_data.loc[rero_data['author_heading'].str.contains("Desvallières, Georges", na=False)])
display(rero_concord.loc[rero_concord['main_form'].str.contains("Desvallières, Georges", na=False)])
# Out:
#            rero_id   idref_id                      author_heading  \
# 839975  A023957387  050433180  Desvallières, Georges, 1861-1950
#
#        subject_heading
# 839975             NaN
#                          id             id_rnv id_rero   id_rero_a  \
# 968721           1010073363                NaN     NaN  A010073363
# 1056650  981023302855002851  (RNV_A)0000113805     NaN  A023957387
#
#                                   main_form          repo_id
# 968721              Desvallières, Georges                rnv
# 1056650  Desvallières, Georges, 1861-1950    rnv-nz-auth-atc

# %% [markdown]
# The number in `rero_id` in `rero_data` corresponds to the last part of either `id_rero` or `id_rero_a` in `rero_concord`. All need to be trimmed of their control characters before they can be used as matchpoints.

# %%
rero_data['id_rero_join'] = rero_data.rero_id.str.extract('(\d+)')
rero_concord['id_rero_join'] = rero_concord['id_rero'].fillna(rero_concord['id_rero_a'])
rero_concord['id_rero_join'] = rero_concord.id_rero_join.str.extract('(\d+)')
display(rero_data.query('id_rero_join == "000036058"'))
display(rero_data.query('id_rero_join == "023957387"'))
display(rero_concord.query('id_rero_join == "000036058"'))
display(rero_concord.query('id_rero_join == "023957387"'))
# Out:
#          rero_id   idref_id               author_heading subject_heading  \
# 6474  A000036058  033273901  Christen-Gueissaz, Eliane               NaN
#
#      id_rero_join
# 6474    000036058
#            rero_id   idref_id                      author_heading  \
# 839975  A023957387  050433180  Desvallières, Georges, 1861-1950
#
#        subject_heading id_rero_join
# 839975             NaN    023957387
#                    id             id_rnv              id_rero id_rero_a  \
# 3  981023303674702851  (RNV_A)0000149055  (RERO)vtls000036058       NaN
#
#                      main_form          repo_id id_rero_join
# 3  Christen-Gueissaz, Eliane    rnv-nz-auth-atc    000036058
#                          id             id_rnv id_rero   id_rero_a  \
# 1056650  981023302855002851  (RNV_A)0000113805     NaN  A023957387
#
#                                   main_form          repo_id id_rero_join
# 1056650  Desvallières, Georges, 1861-1950    rnv-nz-auth-atc    023957387

# %% [markdown]
# Now we can try merging the two tables

# %%
rero_aligns = pd.merge(rero_data, rero_concord, on='id_rero_join', how="inner")
rero_aligns['source'] = rero_aligns['id']
rero_aligns['cible'] = rero_aligns['idref_id']
display(rero_aligns.query('id_rero_join == "000036058"'))
display(rero_aligns.query('id_rero_join == "023957387"'))
print('Nombre de concordiances RERO-IdRef validées: ' + str(len(rero_aligns)))
# Out:
#          rero_id   idref_id               author_heading subject_heading  \
# 6474  A000036058  033273901  Christen-Gueissaz, Eliane               NaN
#
#      id_rero_join                  id             id_rnv              id_rero  \
# 6474    000036058  981023303674702851  (RNV_A)0000149055  (RERO)vtls000036058
#
#      id_rero_a                    main_form          repo_id  \
# 6474       NaN  Christen-Gueissaz, Eliane    rnv-nz-auth-atc
#
#                   source      cible
# 6474  981023303674702851  033273901
#            rero_id   idref_id                      author_heading  \
# 547307  A023957387  050433180  Desvallières, Georges, 1861-1950
#
#        subject_heading id_rero_join                  id             id_rnv  \
# 547307             NaN    023957387  981023302855002851  (RNV_A)0000113805
#
#        id_rero   id_rero_a                           main_form  \
# 547307     NaN  A023957387  Desvallières, Georges, 1861-1950
#
#                 repo_id              source      cible
# 547307  rnv-nz-auth-atc  981023302855002851  050433180
# Nombre de concordiances RERO-IdRef validées: 595757

# %% [markdown]
# Now we have a reference file to benchmark against.
#
# Let's look at Ouali's output next:

# %%
ouali_data['source'] = ouali_data['id source']
ouali_data['cible'] = ouali_data['id cible']
# .copy() is necessary to avoid SettingWithCopyWarning when using datacompy later
ouali_align = ouali_data.query('`nombre de candidats` != 0 & `décision d\'alignement` == "auto"').copy()
ouali_no_align = ouali_data.query('`nombre de candidats` == 0 & `décision d\'alignement` == "auto"').copy()

print('Alignements: ' + str(len(ouali_align)))
print('Non-alignements: ' + str(len(ouali_no_align)))
# Out:
# Alignements: 993694
# Non-alignements: 0

# %%
display(ouali_align)
display(rero_aligns)
# Out:
#        réservoir source           id source      forme principale source  \
# 0       rnv-nz-auth-atc  981023336220602851             Melossi, Dario
# 1       rnv-nz-auth-atc  981023354214602851            Ugelstad, Endre
# 2       rnv-nz-auth-atc  981023335918202851          Meinicke, Michael
# 3       rnv-nz-auth-atc  981023292394002851            Hrozny, Bedřich
# 4       rnv-nz-auth-atc  981023401035502851               Lauzon, Jean
# ...                 ...                 ...                          ...
# 993689  rnv-nz-auth-atc  981023307069702851   Basedow, Johann-Bernhard
# 993690  rnv-nz-auth-atc  981023306039602851             Ingleby, David
# 993691  rnv-nz-auth-atc  981023349559402851  Touchard-Lafosse, Georges
# 993692  rnv-nz-auth-atc  981023400255402851          Desarzens, Victor
# 993693  rnv-nz-auth-atc  981023445319702851      Rotenhan, Christina von
#
#        arbitre date d'arbitrage niveau de confiance commentaire  \
# 0          NaN              NaN                 NaN         NaN
# 1          NaN              NaN                 NaN         NaN
# 2          NaN              NaN                 NaN         NaN
# 3          NaN              NaN                 NaN         NaN
# 4          NaN              NaN                 NaN         NaN
# ...        ...              ...                 ...         ...
# 993689     NaN              NaN                 NaN         NaN
# 993690     NaN              NaN                 NaN         NaN
# 993691     NaN              NaN                 NaN         NaN
# 993692     NaN              NaN                 NaN         NaN
# 993693     NaN              NaN                 NaN         NaN
#
#        décision d'alignement nombre de candidats score max  ...  \
# 0                       auto                   1      0.60  ...
# 1                       auto                   0       NaN  ...
# 2                       auto                   1      0.61  ...
# 3                       auto                   1      0.60  ...
# 4                       auto                   2      0.56  ...
# ...                      ...                 ...       ...  ...
# 993689                  auto                   1      0.60  ...
# 993690                  auto                   1      0.65  ...
# 993691                  auto                   1      0.62  ...
# 993692                  auto                   1      0.61  ...
# 993693                  auto                   1      0.62  ...
#
#        type de cible 2 réservoir cible 2 id cible 2 forme principale cible 2  \
# 0                  NaN               NaN        NaN                      NaN
# 1                  NaN               NaN        NaN                      NaN
# 2                  NaN               NaN        NaN                      NaN
# 3                  NaN               NaN        NaN                      NaN
# 4                  NaN               NaN        NaN                      NaN
# ...                ...               ...        ...                      ...
# 993689             NaN               NaN        NaN                      NaN
# 993690             NaN               NaN        NaN                      NaN
# 993691             NaN               NaN        NaN                      NaN
# 993692             NaN               NaN        NaN                      NaN
# 993693             NaN               NaN        NaN                      NaN
#
#        type de cible 3 réservoir cible 3 id cible 3 forme principale cible 3  \
# 0                  NaN               NaN        NaN                      NaN
# 1                  NaN               NaN        NaN                      NaN
# 2                  NaN               NaN        NaN                      NaN
# 3                  NaN               NaN        NaN                      NaN
# 4                  NaN               NaN        NaN                      NaN
# ...                ...               ...        ...                      ...
# 993689             NaN               NaN        NaN                      NaN
# 993690             NaN               NaN        NaN                      NaN
# 993691             NaN               NaN        NaN                      NaN
# 993692             NaN               NaN        NaN                      NaN
# 993693             NaN               NaN        NaN                      NaN
#
#                     source      cible
# 0       981023336220602851  050194798
# 1       981023354214602851        NaN
# 2       981023335918202851  100939848
# 3       981023292394002851  079549322
# 4       981023401035502851  153084596
# ...                    ...        ...
# 993689  981023307069702851  06117422X
# 993690  981023306039602851  056761503
# 993691  981023349559402851  027166333
# 993692  981023400255402851  031402569
# 993693  981023445319702851  191218642
#
# [993694 rows x 24 columns]
#            rero_id   idref_id  \
# 0       A000000276  027262782
# 1       A000000496  086950673
# 2       A000000519  104516852
# 3       A000000531  02917516X
# 4       A000000555  029274702
# ...            ...        ...
# 595752  A026544323  238137511
# 595753  A026545232  189034556
# 595754  A026553056  25523001X
# 595755  A026553270  172802598
# 595756  A026559379  244008124
#
#                                            author_heading    subject_heading  \
# 0       Lyon (1450-1800, lieu d'édition ou d'impressio...                NaN
# 1                                           2 Unlimited                  NaN
# 2                            Repington, Charles à Court                  NaN
# 3                                              A, Cheng                  NaN
# 4                    A.G. Leventis Foundation (Nicosia)                  NaN
# ...                                                   ...                ...
# 595752                ????????, ?. ?. (???? ??????????)                  NaN
# 595753                            Jaeger, Thomas, 1977-                  NaN
# 595754                                                NaN     Hänggi, Yves
# 595755                                 Hecht, Susanna B.                 NaN
# 595756                                                NaN  Gapany, Johanna
#
#        id_rero_join                  id             id_rnv  \
# 0         000000276  981023297288102851  (RNV_A)0000775749
# 1         000000496  981023283256402851  (RNV_A)0000893383
# 2         000000519  981023296087902851  (RNV_A)0000714252
# 3         000000531  981023293328902851  (RNV_A)0000957889
# 4         000000555  981023298664702851  (RNV_A)0000842390
# ...             ...                 ...                ...
# 595752    026544323  981023290466102851  (RNV_A)0000851050
# 595753    026545232  981023299732602851  (RNV_A)0000755755
# 595754    026553056          1026553056                NaN
# 595755    026553270  981023400205802851  (RNV_A)0001434674
# 595756    026559379          1026559379                NaN
#
#                     id_rero   id_rero_a  \
# 0                       NaN  A000000276
# 1                       NaN  A000000496
# 2                       NaN  A000000519
# 3                       NaN  A000000531
# 4                       NaN  A000000555
# ...                     ...         ...
# 595752                  NaN  A026544323
# 595753                  NaN  A026545232
# 595754                  NaN  A026553056
# 595755  (RERO)vtls026553270         NaN
# 595756                  NaN  A026559379
#
#                                                 main_form          repo_id  \
# 0       Lyon (1450-1800, lieu d'édition ou d'impressio...  rnv-nz-auth-atc
# 1                                           2 Unlimited    rnv-nz-auth-atc
# 2                            Repington, Charles à Court    rnv-nz-auth-atc
# 3                                              A, Cheng    rnv-nz-auth-atc
# 4                    A.G. Leventis Foundation (Nicosia)    rnv-nz-auth-atc
# ...                                                   ...              ...
# 595752                Старилов, Ю. Н. (Юрий Николаевич)    rnv-nz-auth-atc
# 595753                            Jaeger, Thomas, 1977-    rnv-nz-auth-atc
# 595754                                     Hänggi, Yves                rnv
# 595755                           Hecht, Susanna Bettina    rnv-nz-auth-atc
# 595756                                  Gapany, Johanna                rnv
#
#                     source      cible
# 0       981023297288102851  027262782
# 1       981023283256402851  086950673
# 2       981023296087902851  104516852
# 3       981023293328902851  02917516X
# 4       981023298664702851  029274702
# ...                    ...        ...
# 595752  981023290466102851  238137511
# 595753  981023299732602851  189034556
# 595754          1026553056  25523001X
# 595755  981023400205802851  172802598
# 595756          1026559379  244008124
#
# [595757 rows x 13 columns]

# %%
compare = datacompy.Compare(rero_aligns, ouali_align, join_columns=['source', 'cible'], 
                            df1_name='RERO Benchmark', df2_name='Ouali')
print(compare.report())
# Out:
# DataComPy Comparison
# --------------------
#
# DataFrame Summary
# -----------------
#
#         DataFrame  Columns    Rows
# 0  RERO Benchmark       13  595757
# 1           Ouali       24  993694
#
# Column Summary
# --------------
#
# Number of columns in common: 2
# Number of columns in RERO Benchmark but not in Ouali: 11
# Number of columns in Ouali but not in RERO Benchmark: 22
#
# Row Summary
# -----------
#
# Matched on: source, cible
# Any duplicates on match values: Yes
# Absolute Tolerance: 0
# Relative Tolerance: 0
# Number of rows in common: 406,918
# Number of rows in RERO Benchmark but not in Ouali: 188,839
# Number of rows in Ouali but not in RERO Benchmark: 586,776
#
# Number of rows with some compared columns unequal: 0
# Number of rows with all compared columns equal: 406,918
#
# Column Comparison
# -----------------
#
# Number of columns compared with some values unequal: 0
# Number of columns compared with all values equal: 2
# Total number of values which compare unequal: 0
#
# Sample Rows Only in RERO Benchmark (First 10 Columns)
# -----------------------------------------------------
#
#            rero_id   idref_id                         author_heading                             subject_heading id_rero_join                  id             id_rnv              id_rero   id_rero_a                                   main_form
# 467133  A016363890  154474088                                    NaN                       Zeynek, Theodor von      016363890          1016363890                NaN                  NaN  A016363890                       Zeynek, Theodor von
# 498809  A018713411  029160359                                    NaN                          Benameur, Jeanne      018713411          1018713411                NaN                  NaN  A018713411                          Benameur, Jeanne
# 94003   A003165599  055798535                  Delaporte, Florence                                           NaN    003165599  981023316253302851  (RNV_A)0000031380  (RERO)vtls003165599         NaN                       Delaporte, Florence
# 397188  A011648687  034702679                                    NaN  Canberra (Australie, territoire fédéral)      011648687          1011648687                NaN                  NaN  A011648687  Canberra (Australie, territoire fédéral)
# 366350  A010143229  114654417                                    NaN                    Rothschild, Maurice de      010143229          1010143229                NaN                  NaN  A010143229                    Rothschild, Maurice de
# 245906  A003841683  131355473  Societas pro fauna et flora Fennica                                           NaN    003841683  981023347714202851  (RNV_A)0000470243  (RERO)vtls003841683         NaN       Societas pro fauna et flora Fennica
# 444501  A013527517  244073759   Chilingari?a?n, Artem Sogomonovich                                           NaN    013527517  981023295210402851  (RNV_A)0000715895                  NaN  A013527517        Chilingari︠a︡n, Artem Sogomonovich
# 467746  A016393994  172315158              Möller, Jean, 1806-1862                                           NaN    016393994  981023287564402851  (RNV_A)0000730887                  NaN  A016393994                   Möller, Jean, 1806-1862
# 371895  A010168848  027202216                                    NaN                          Zahan, Dominique      010168848          1010168848                NaN                  NaN  A010168848                          Zahan, Dominique
# 212691  A003694718  17806405X                       Pilgrim, David                                           NaN    003694718  981023339694402851  (RNV_A)0000489499  (RERO)vtls003694718         NaN                            Pilgrim, David
#
# Sample Rows Only in Ouali (First 10 Columns)
# --------------------------------------------
#
#         réservoir source           id source          forme principale source arbitre date d'arbitrage niveau de confiance commentaire décision d'alignement nombre de candidats score max
# 873755   rnv-nz-auth-atc  981023376108702851             Longo, Jean-Michel       NaN              NaN                 NaN         NaN                  auto                   0       NaN
# 1127882  rnv-nz-auth-atc  981023485729402851                Chabaud, Matthieu     NaN              NaN                 NaN         NaN                  auto                   1      0.67
# 758590   rnv-nz-auth-atc  981023354106002851        Vaullet, Claude-Bernard       NaN              NaN                 NaN         NaN                  auto                   0       NaN
# 1170999  rnv-nz-auth-atc  981023323925802851            Goron, Jean-Jacques       NaN              NaN                 NaN         NaN                  auto                   0       NaN
# 656424   rnv-nz-auth-atc  981023305167802851  André, Charles Louis François       NaN              NaN                 NaN         NaN                  auto                   1      0.58
# 946148   rnv-nz-auth-atc  981023383567802851             Tschirren, Klemens       NaN              NaN                 NaN         NaN                  auto                   0       NaN
# 656779   rnv-nz-auth-atc  981023375520702851      Marchesi, Mario, musicien       NaN              NaN                 NaN         NaN                  auto                   1      0.52
# 611394   rnv-nz-auth-atc  981023383596502851               Burba, Magdalena       NaN              NaN                 NaN         NaN                  auto                   0       NaN
# 749648   rnv-nz-auth-atc  981023489232902851                      Lucot, Éric     NaN              NaN                 NaN         NaN                  auto                   1      0.62
# 1038263  rnv-nz-auth-atc  981023350444802851         Thomas, Donald Serrell       NaN              NaN                 NaN         NaN                  auto                   1      0.60

# %%
common_align = pd.merge(bench_align, ouali_align, on=['id source', 'id cible'], how='inner')

# %%
common_align
# Out:
#        réservoir source_x           id source       forme principale source_x  \
# 0         rnv-nz-auth-atc  981023336220602851                Melossi, Dario
# 1         rnv-nz-auth-atc  981023335918202851             Meinicke, Michael
# 2         rnv-nz-auth-atc  981023401035502851                  Lauzon, Jean
# 3         rnv-nz-auth-atc  981023355887602851  Dowbiggin, Ian Robert, 1952-
# 4         rnv-nz-auth-atc  981023336067602851                  Maccoy, Seth
# ...                   ...                 ...                             ...
# 564237    rnv-nz-auth-atc  981023307069702851      Basedow, Johann-Bernhard
# 564238    rnv-nz-auth-atc  981023306039602851                Ingleby, David
# 564239    rnv-nz-auth-atc  981023349559402851     Touchard-Lafosse, Georges
# 564240    rnv-nz-auth-atc  981023400255402851             Desarzens, Victor
# 564241    rnv-nz-auth-atc  981023445319702851         Rotenhan, Christina von
#
#         arbitre_x  date d'arbitrage_x  niveau de confiance_x  commentaire_x  \
# 0             NaN                 NaN                    NaN            NaN
# 1             NaN                 NaN                    NaN            NaN
# 2             NaN                 NaN                    NaN            NaN
# 3             NaN                 NaN                    NaN            NaN
# 4             NaN                 NaN                    NaN            NaN
# ...           ...                 ...                    ...            ...
# 564237        NaN                 NaN                    NaN            NaN
# 564238        NaN                 NaN                    NaN            NaN
# 564239        NaN                 NaN                    NaN            NaN
# 564240        NaN                 NaN                    NaN            NaN
# 564241        NaN                 NaN                    NaN            NaN
#
#        décision d'alignement_x  nombre de candidats_x  score max_x  ...  \
# 0                         auto                      1         0.60  ...
# 1                         auto                      1         0.61  ...
# 2                         auto                      2         0.56  ...
# 3                         auto                      1         0.60  ...
# 4                         auto                      1         0.55  ...
# ...                        ...                    ...          ...  ...
# 564237                    auto                      1         0.60  ...
# 564238                    auto                      1         0.65  ...
# 564239                    auto                      1         0.62  ...
# 564240                    auto                      1         0.61  ...
# 564241                    auto                      1         0.62  ...
#
#        réservoir cible_y             forme principale cible_y  \
# 0                  idref             Melossi, Dario 1948-....
# 1                  idref          Meinicke, Michael 19..-....
# 2                  idref               lauzon, Jean 1953-....
# 3                  idref                Dowbiggin, Ian Robert
# 4                  idref                McCoy, Seth 1928-....
# ...                  ...                                  ...
# 564237             idref   Basedow, Johann Bernhard 1724-1790
# 564238             idref                       Ingleby, David
# 564239             idref  Touchard-Lafosse, Georges 1780-1847
# 564240             idref          Desarzens, Victor 1908-1986
# 564241             idref    Rotenhan, Christina von 19..-....
#
#        type de cible 2_y réservoir cible 2_y  id cible 2_y  \
# 0                    NaN                 NaN           NaN
# 1                    NaN                 NaN           NaN
# 2                    NaN                 NaN           NaN
# 3                    NaN                 NaN           NaN
# 4                    NaN                 NaN           NaN
# ...                  ...                 ...           ...
# 564237               NaN                 NaN           NaN
# 564238               NaN                 NaN           NaN
# 564239               NaN                 NaN           NaN
# 564240               NaN                 NaN           NaN
# 564241               NaN                 NaN           NaN
#
#         forme principale cible 2_y  type de cible 3_y  réservoir cible 3_y  \
# 0                              NaN                NaN                  NaN
# 1                              NaN                NaN                  NaN
# 2                              NaN                NaN                  NaN
# 3                              NaN                NaN                  NaN
# 4                              NaN                NaN                  NaN
# ...                            ...                ...                  ...
# 564237                         NaN                NaN                  NaN
# 564238                         NaN                NaN                  NaN
# 564239                         NaN                NaN                  NaN
# 564240                         NaN                NaN                  NaN
# 564241                         NaN                NaN                  NaN
#
#         id cible 3_y  forme principale cible 3_y
# 0                NaN                         NaN
# 1                NaN                         NaN
# 2                NaN                         NaN
# 3                NaN                         NaN
# 4                NaN                         NaN
# ...              ...                         ...
# 564237           NaN                         NaN
# 564238           NaN                         NaN
# 564239           NaN                         NaN
# 564240           NaN                         NaN
# 564241           NaN                         NaN
#
# [564242 rows x 42 columns]
