# %%
import pandas as pd
import datacompy
benchmark_file = 'input/benchmark-nomsATC.tsv'
rero_files = ['input/RERO-aligned-2021-11.txt', 'input/RERO-google-extract-20220330.tsv']
rero_concord_file = 'input/20220228_concordances_id_rnv_id_rero_4_headings.csv'

error_file = 'output/erreurs-nomsATC.csv'
missing_file = 'output/manquants-nomsATC.csv'

# %% [markdown]
# Import all data into dataframes. Specifying the `dtype` appears necessary because otherwise pandas doesn't know what to do with columns containing both numbers and text.

# %%
ouali_data = pd.read_csv(benchmark_file, sep='\t', dtype = str)
rero_data = pd.concat((pd.read_csv(f, sep='\t', encoding = "ISO-8859-1", dtype = str) for f in rero_files))
rero_data.columns =[column.replace(" ", "_") for column in rero_data.columns]
# Remove any duplicate entries between the RERO extracts
rero_data.drop_duplicates(subset=['rero_id'],inplace=True)
rero_concord = pd.read_csv(rero_concord_file, dtype = str)

# %%
print("Nombre de concordances validées dans le fichier RERO: ",len(rero_data))
# Out:
# Nombre de concordances validées dans le fichier RERO:  25511

# %% [markdown]
# Not sure why the dataframe query doesn't seem to work with strings. Maybe because of extra spaces? Using loc and contains works better. `na=False` is required because that column contains `NaN` data, which we need to convert to false in order to use loc lookup.

# %%
display(rero_data.loc[rero_data['author_heading'].str.contains("Dietrich, Andreas", na=False)])
display(rero_concord.loc[rero_concord['main_form'].str.contains("Dietrich, Andreas", na=False)])
# Out:
#          rero_id   idref_id       author_heading subject_heading
# 4375  A003180228  257367934  Dietrich, Andreas               NaN
#                         id             id_rnv              id_rero id_rero_a  \
# 124357  981023317235702851  (RNV_A)0000071017  (RERO)vtls003180228       NaN
# 761184  981023380231902851  (RNV_A)0001220989  (RERO)vtls014190124       NaN
#
#                          main_form          repo_id
# 124357         Dietrich, Andreas    rnv-nz-auth-atc
# 761184  Dietrich, Andreas, 1976-    rnv-nz-auth-atc

# %% [markdown]
# The number in `rero_id` in `rero_data` corresponds to the last part of either `id_rero` or `id_rero_a` in `rero_concord`. All need to be trimmed of their control characters before they can be used as matchpoints.

# %%
rero_data['id_rero_join'] = rero_data.rero_id.str.extract('(\d+)')
rero_concord['id_rero_join'] = rero_concord['id_rero'].fillna(rero_concord['id_rero_a'])
rero_concord['id_rero_join'] = rero_concord.id_rero_join.str.extract('(\d+)')
display(rero_data.query('id_rero_join == "003180228"'))
display(rero_concord.query('id_rero_join == "003180228"'))
# Out:
#          rero_id   idref_id       author_heading subject_heading id_rero_join
# 4375  A003180228  257367934  Dietrich, Andreas               NaN    003180228
#                         id             id_rnv              id_rero id_rero_a  \
# 124357  981023317235702851  (RNV_A)0000071017  (RERO)vtls003180228       NaN
#
#                   main_form          repo_id id_rero_join
# 124357  Dietrich, Andreas    rnv-nz-auth-atc    003180228

# %% [markdown]
# Now we can try merging the two tables

# %%
rero_aligns = pd.merge(rero_data, rero_concord, on='id_rero_join', how="inner")
rero_aligns['source'] = rero_aligns['id']
rero_aligns['cible'] = rero_aligns['idref_id']
display(rero_aligns.query('id_rero_join == "003180228"'))
print('Nombre de concordiances RERO-IdRef validées: ' + str(len(rero_aligns)))
# Out:
#          rero_id   idref_id       author_heading subject_heading id_rero_join  \
# 4331  A003180228  257367934  Dietrich, Andreas               NaN    003180228
#
#                       id             id_rnv              id_rero id_rero_a  \
# 4331  981023317235702851  (RNV_A)0000071017  (RERO)vtls003180228       NaN
#
#                 main_form          repo_id              source      cible
# 4331  Dietrich, Andreas    rnv-nz-auth-atc  981023317235702851  257367934
# Nombre de concordiances RERO-IdRef validées: 20372

# %% [markdown]
# Now we have a reference file to benchmark against.
#
# Let's look at Ouali's output next:

# %%
ouali_data['source'] = ouali_data['id source']
ouali_data['cible'] = ouali_data['id cible']
# .copy() is necessary to avoid SettingWithCopyWarning when using datacompy later
ouali_align = ouali_data.query('`nombre de candidats` != "0" & `décision d\'alignement` == "auto"').copy()
ouali_no_align = ouali_data.query('`nombre de candidats` == "0" & `décision d\'alignement` == "auto"').copy()

print('Alignements: ' + str(len(ouali_align)))
print('Non-alignements: ' + str(len(ouali_no_align)))
# Out:
# Alignements: 641618
# Non-alignements: 352076

# %%
display(ouali_align)
display(rero_aligns)
# Out:
#        réservoir source           id source         forme principale source  \
# 0       rnv-nz-auth-atc  981023336220602851                Melossi, Dario
# 2       rnv-nz-auth-atc  981023335918202851             Meinicke, Michael
# 3       rnv-nz-auth-atc  981023292394002851               Hrozny, Bedřich
# 4       rnv-nz-auth-atc  981023401035502851                  Lauzon, Jean
# 5       rnv-nz-auth-atc  981023355887602851  Dowbiggin, Ian Robert, 1952-
# ...                 ...                 ...                             ...
# 993689  rnv-nz-auth-atc  981023307069702851      Basedow, Johann-Bernhard
# 993690  rnv-nz-auth-atc  981023306039602851                Ingleby, David
# 993691  rnv-nz-auth-atc  981023349559402851     Touchard-Lafosse, Georges
# 993692  rnv-nz-auth-atc  981023400255402851             Desarzens, Victor
# 993693  rnv-nz-auth-atc  981023445319702851         Rotenhan, Christina von
#
#        arbitre date d'arbitrage niveau de confiance commentaire  \
# 0          NaN              NaN                 NaN         NaN
# 2          NaN              NaN                 NaN         NaN
# 3          NaN              NaN                 NaN         NaN
# 4          NaN              NaN                 NaN         NaN
# 5          NaN              NaN                 NaN         NaN
# ...        ...              ...                 ...         ...
# 993689     NaN              NaN                 NaN         NaN
# 993690     NaN              NaN                 NaN         NaN
# 993691     NaN              NaN                 NaN         NaN
# 993692     NaN              NaN                 NaN         NaN
# 993693     NaN              NaN                 NaN         NaN
#
#        décision d'alignement nombre de candidats score max  ...  \
# 0                       auto                   1      0.60  ...
# 2                       auto                   1      0.61  ...
# 3                       auto                   1      0.60  ...
# 4                       auto                   2      0.56  ...
# 5                       auto                   1      0.60  ...
# ...                      ...                 ...       ...  ...
# 993689                  auto                   1      0.60  ...
# 993690                  auto                   1      0.65  ...
# 993691                  auto                   1      0.62  ...
# 993692                  auto                   1      0.61  ...
# 993693                  auto                   1      0.62  ...
#
#        type de cible 2 réservoir cible 2 id cible 2 forme principale cible 2  \
# 0                  NaN               NaN        NaN                      NaN
# 2                  NaN               NaN        NaN                      NaN
# 3                  NaN               NaN        NaN                      NaN
# 4                  NaN               NaN        NaN                      NaN
# 5                  NaN               NaN        NaN                      NaN
# ...                ...               ...        ...                      ...
# 993689             NaN               NaN        NaN                      NaN
# 993690             NaN               NaN        NaN                      NaN
# 993691             NaN               NaN        NaN                      NaN
# 993692             NaN               NaN        NaN                      NaN
# 993693             NaN               NaN        NaN                      NaN
#
#        type de cible 3 réservoir cible 3 id cible 3 forme principale cible 3  \
# 0                  NaN               NaN        NaN                      NaN
# 2                  NaN               NaN        NaN                      NaN
# 3                  NaN               NaN        NaN                      NaN
# 4                  NaN               NaN        NaN                      NaN
# 5                  NaN               NaN        NaN                      NaN
# ...                ...               ...        ...                      ...
# 993689             NaN               NaN        NaN                      NaN
# 993690             NaN               NaN        NaN                      NaN
# 993691             NaN               NaN        NaN                      NaN
# 993692             NaN               NaN        NaN                      NaN
# 993693             NaN               NaN        NaN                      NaN
#
#                     source      cible
# 0       981023336220602851  050194798
# 2       981023335918202851  100939848
# 3       981023292394002851  079549322
# 4       981023401035502851  153084596
# 5       981023355887602851  031772609
# ...                    ...        ...
# 993689  981023307069702851  06117422X
# 993690  981023306039602851  056761503
# 993691  981023349559402851  027166333
# 993692  981023400255402851  031402569
# 993693  981023445319702851  191218642
#
# [641618 rows x 24 columns]
#           rero_id   idref_id  \
# 0      A000000028  171781686
# 1      A000000037  027375188
# 2      A000000039  029089565
# 3      A000000042  027522938
# 4      A000000047  027220427
# ...           ...        ...
# 20367  A010225830  261385917
# 20368  A010038347  261393340
# 20369  A010225105  261393561
# 20370  A017772669  261394398
# 20371  A021963085  261395416
#
#                                           author_heading subject_heading  \
# 0      Altdorf (Deutschland ; 1450-1800, lieu d'éditi...             NaN
# 1      Amsterdam (1450-1800, lieu d'édition ou d'impr...             NaN
# 2      Ansbach (1450-1800, lieu d'édition ou d'impres...             NaN
# 3      Antwerpen (1450-1800, lieu d'édition ou d'impr...             NaN
# 4      Augsburg (1450-1800, lieu d'édition ou d'impre...             NaN
# ...                                                  ...             ...
# 20367       Le Locle (Suisse, NE) - Impasse du Lion-d'Or             NaN
# 20368            Le Locle (Suisse, NE) - La Bourdonnière             NaN
# 20369         Le Locle (Suisse, NE) - Maison de paroisse             NaN
# 20370                  Le Locle (Suisse, NE) - Montpugin             NaN
# 20371   Le Locle (Suisse, NE) - Monument Jules Grossmann             NaN
#
#       id_rero_join                  id             id_rnv id_rero   id_rero_a  \
# 0        000000028  981023300652902851  (RNV_A)0000020879     NaN  A000000028
# 1        000000037  981023291273702851  (RNV_A)0000873517     NaN  A000000037
# 2        000000039  981023284869802851  (RNV_A)0000956670     NaN  A000000039
# 3        000000042  981023284869702851  (RNV_A)0000955971     NaN  A000000042
# 4        000000047  981023297672102851  (RNV_A)0000792061     NaN  A000000047
# ...            ...                 ...                ...     ...         ...
# 20367    010225830          1010225830                NaN     NaN  A010225830
# 20368    010038347          1010038348                NaN     NaN  A010038347
# 20369    010225105          1010225105                NaN     NaN  A010225105
# 20370    017772669          1017772669                NaN     NaN  A017772669
# 20371    021963085          1021963085                NaN     NaN  A021963085
#
#                                                main_form          repo_id  \
# 0      Altdorf (Deutschland ; 1450-1800, lieu d'éditi...  rnv-nz-auth-atc
# 1      Amsterdam (1450-1800, lieu d'édition ou d'impr...  rnv-nz-auth-atc
# 2      Ansbach (1450-1800, lieu d'édition ou d'impres...  rnv-nz-auth-atc
# 3      Antwerpen (1450-1800, lieu d'édition ou d'impr...  rnv-nz-auth-atc
# 4      Augsburg (1450-1800, lieu d'édition ou d'impre...  rnv-nz-auth-atc
# ...                                                  ...              ...
# 20367     Le Locle (Suisse, NE) - Impasse du Lion-d'Or                rnv
# 20368          Le Locle (Suisse, NE) - La Bourdonnière                rnv
# 20369       Le Locle (Suisse, NE) - Maison de paroisse                rnv
# 20370                Le Locle (Suisse, NE) - Montpugin                rnv
# 20371      Chapallaz, René. "Monument Jules Grossmann"                rnv
#
#                    source      cible
# 0      981023300652902851  171781686
# 1      981023291273702851  027375188
# 2      981023284869802851  029089565
# 3      981023284869702851  027522938
# 4      981023297672102851  027220427
# ...                   ...        ...
# 20367          1010225830  261385917
# 20368          1010038348  261393340
# 20369          1010225105  261393561
# 20370          1017772669  261394398
# 20371          1021963085  261395416
#
# [20372 rows x 13 columns]

# %%
common_source = pd.merge(rero_aligns, ouali_align, how="inner", on='source', suffixes=("_rero", "_ouali"), copy=True)
print("Alignements Ouali présents dans fichier RERO: ", len(common_source))
# Out:
# Alignements Ouali présents dans fichier RERO:  4858

# %%
common_target = pd.merge(rero_aligns, ouali_align, how="inner", on=['source', 'cible'], suffixes=("_rero", "_ouali"), copy=True)
print("Alignements Ouali validés par RERO: ", len(common_target))
print("Pourcentage validé: ", len(common_target)/len(common_source)*100, "%")
# Out:
# Alignements Ouali validés par RERO:  4699
# Pourcentage validé:  96.72704816797035 %

# %%
divergences = common_source.loc[~(common_source['cible_rero'] == common_source['cible_ouali'])]
display(divergences[['source','cible_ouali','cible_rero','forme principale cible','main_form']])
divergences.to_csv(error_file,columns=['source','cible_ouali','cible_rero','forme principale cible','main_form'],encoding="UTF-8",index=False)
# Out:
#                   source cible_ouali  cible_rero  \
# 0     981023292733602851   098879456   117789259
# 13    981023285513602851   137125097   030384109
# 21    981023291275002851   070455317   032474423
# 22    981023296833702851   152792961   026685493
# 29    981023285003102851   030945054   167540831
# ...                  ...         ...         ...
# 4789  981023369854902851   258939575  258939575
# 4816  981023298851002851   253657199   257106049
# 4829  981023304204802851   076453650   259846554
# 4831  981023287378202851   150125666   068552963
# 4854  981023281718302851   139698019   260913812
#
#                    forme principale cible  \
# 0                    Abū Zahraẗ, Muḥammad
# 13                    Albert von Augsburg
# 21            Ammonios Saccas 0175?-0242?
# 22    Anastase le Sinaïte saint 05..-0599
# 29                Antonin saint 1389-1459
# ...                                   ...
# 4789               Boss, Sabine 1966-....
# 4816    Pury, Charles Albert de 1752-1833
# 4829          Feller, Christian 1943-....
# 4831                        Bouyer, A.-C.
# 4854                Kempter, Lothar 1900-
#
#                                       main_form
# 0            Abū Zahrah, Muḥammad, 1898-1974
# 13                       Albertus, De Saxonia
# 21                         Ammonius, Hermeiou
# 22                        Anastasius, Sinaita
# 29    Antonino, archevêque de Florence, saint
# ...                                         ...
# 4789                             Boss, Sabine
# 4816       Pury, Charles Albert de, 1713-1790
# 4829      Feller, Christian, expert-comptable
# 4831  Courcier, veuve de Louis, fl. 1811-1821
# 4854               Kempter, Lothar, 1844-1918
#
# [159 rows x 5 columns]

# %%
missed = pd.merge(rero_aligns, ouali_no_align, how="inner", on='source', suffixes=("_rero", "_ouali"), copy=True)
display(missed[['source','cible_ouali','cible_rero','forme principale cible','main_form']])
missed.to_csv(missing_file,columns=['source','cible_ouali','cible_rero','forme principale cible','main_form'],encoding="UTF-8",index=False)
print("Alignements RERO manqués par Ouali: ", len(missed))
# Out:
#                  source cible_ouali cible_rero forme principale cible  \
# 0    981023302389702851         NaN  256648107                    NaN
# 1    981023303730702851         NaN  115972463                    NaN
# 2    981023300411502851         NaN  03394265X                    NaN
# 3    981023291573902851         NaN  032211414                    NaN
# 4    981023289136502851         NaN  03478375X                    NaN
# ..                  ...         ...        ...                    ...
# 177  981023365104302851         NaN  261383205                    NaN
# 178  981023357333702851         NaN  261383701                    NaN
# 179  981023348417402851         NaN  261219642                    NaN
# 180  981023357657102851         NaN  261383205                    NaN
# 181  981023345807502851         NaN  261393294                    NaN
#
#                                 main_form
# 0                Corrêa, Ruth Valadares
# 1          Davydov, I︠U︡riĭ Nikolaevich
# 2         Derzhavin, Gavrila Romanovich
# 3                          Font Quer, P
# 4    Ganshina, Klavdii︠a︡ Aleksandrovna
# ..                                    ...
# 177                 Eggendorffer, Aloïs
# 178         Eggendorffer, Aloïs-Wilhelm
# 179                     Staeger, Dieter
# 180                 Eggendorffer, Louis
# 181                Roussy, Albert-Emile
#
# [182 rows x 5 columns]
# Alignements RERO manqués par Ouali:  182

# %%
compare = datacompy.Compare(rero_aligns, ouali_align, join_columns=['source', 'cible'], 
                            df1_name='RERO Benchmark', df2_name='Ouali')
print(compare.report())
# Out:
# DataComPy Comparison
# --------------------
#
# DataFrame Summary
# -----------------
#
#         DataFrame  Columns    Rows
# 0  RERO Benchmark       13   20372
# 1           Ouali       24  641618
#
# Column Summary
# --------------
#
# Number of columns in common: 2
# Number of columns in RERO Benchmark but not in Ouali: 11
# Number of columns in Ouali but not in RERO Benchmark: 22
#
# Row Summary
# -----------
#
# Matched on: source, cible
# Any duplicates on match values: Yes
# Absolute Tolerance: 0
# Relative Tolerance: 0
# Number of rows in common: 4,691
# Number of rows in RERO Benchmark but not in Ouali: 15,681
# Number of rows in Ouali but not in RERO Benchmark: 636,927
#
# Number of rows with some compared columns unequal: 0
# Number of rows with all compared columns equal: 4,691
#
# Column Comparison
# -----------------
#
# Number of columns compared with some values unequal: 0
# Number of columns compared with all values equal: 2
# Total number of values which compare unequal: 0
#
# Sample Rows Only in RERO Benchmark (First 10 Columns)
# -----------------------------------------------------
#
#           rero_id   idref_id                                                        author_heading                                                           subject_heading id_rero_join                  id             id_rnv id_rero   id_rero_a                                                                 main_form
# 2561   A000183960  030503043                         Musée de sculpture en plein air (Antwerpen)                                                                         NaN    000183960  981023285744402851  (RNV_A)0000999702     NaN  A000183960                                Musée de sculpture en plein air (Anvers)
# 10689  A009991754  253819261                                                                   NaN                              Fribourg (Suisse, ville). Conseil communal      009991754          1009991754                NaN     NaN  A009991754                              Fribourg (Suisse, ville). Conseil communal
# 1509   A000109523  027003434                                  Maksimov, Vladimir Emel'i?a?novich                                                                         NaN    000109523  981023295348402851  (RNV_A)0000881386     NaN  A000109523                                      Maksimov, Vladimir Emelʹi︠a︡novich
# 11410  A010016514  028659538                                                                   NaN                                                    Sotheby Parke Bernet      010016514          1010016514                NaN     NaN  A010016514                                                    Sotheby Parke Bernet
# 19972  A010151558  258965916  Société de navigation sur les lacs de Neuchâtel et Morat (Neuchâtel)                                                                       NaN    010151558          1010151558                NaN     NaN  A010151558    Société de navigation sur les lacs de Neuchâtel et Morat (Neuchâtel)
# 16815  A013641555  138919100                                                       Wilbur, 1960-                                                                         NaN    013641555  981023287080102851  (RNV_A)0000709592     NaN  A013641555                                                           Wilbur, 1960-
# 18115  A020205907  026527359                                                                   NaN  Fédération nationale des écoles des parents et des éducateurs (France)      020205907          1020205907                NaN     NaN  A020205907  Fédération nationale des écoles des parents et des éducateurs (France)
# 8231   A005466585  026461056                                          Musée cantonal de Fribourg                                                                         NaN    005466585  981023303069602851  (RNV_A)0000110101     NaN  A005466585                                              Musée cantonal de Fribourg
# 18436  A022593568  23762348X                 Burslem (1450-1800, lieu d'édition ou d'impression)                                                                         NaN    022593568  981023293844202851  (RNV_A)0000985942     NaN  A022593568                     Burslem (1450-1800, lieu d'édition ou d'impression)
# 1321   A000096908  033499578                                                        Kano, Koichi                                                                         NaN    000096908  981023294744802851  (RNV_A)0000693727     NaN  A000096908                                                            Kano, Koichi
#
# Sample Rows Only in Ouali (First 10 Columns)
# --------------------------------------------
#
#        réservoir source           id source        forme principale source arbitre date d'arbitrage niveau de confiance commentaire décision d'alignement nombre de candidats score max
# 413651  rnv-nz-auth-atc  981023305372402851                  Ara, Angelo       NaN              NaN                 NaN         NaN                  auto                   1      0.60
# 305460  rnv-nz-auth-atc  981023341686802851            Perels, Christoph       NaN              NaN                 NaN         NaN                  auto                   1      0.61
# 207038  rnv-nz-auth-atc  981023378981702851            Lacazedieu, Annie       NaN              NaN                 NaN         NaN                  auto                   1      0.65
# 250822  rnv-nz-auth-atc  981023314049702851                    Collis, L       NaN              NaN                 NaN         NaN                  auto                   1      0.56
# 165377  rnv-nz-auth-atc  981023724022702851   Kanellakis, Dimitrios, 1993-     NaN              NaN                 NaN         NaN                  auto                   1      0.63
# 490153  rnv-nz-auth-atc  981023377069302851              Effertz, Tobias       NaN              NaN                 NaN         NaN                  auto                   1      0.65
# 264872  rnv-nz-auth-atc  981023395446102851               Ricour, Damien       NaN              NaN                 NaN         NaN                  auto                   1      0.60
# 579974  rnv-nz-auth-atc  981023300467402851   Stapledon, Reginald George       NaN              NaN                 NaN         NaN                  auto                   1      0.59
# 302877  rnv-nz-auth-atc  981023395647902851  Maillard, Paul-Jules, 1881-       NaN              NaN                 NaN         NaN                  auto                   1      0.58
# 470791  rnv-nz-auth-atc  981023323571102851          Gros, Charles-Marie       NaN              NaN                 NaN         NaN                  auto                   1      0.61
